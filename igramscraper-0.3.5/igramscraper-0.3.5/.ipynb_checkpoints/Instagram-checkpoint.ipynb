# %%
import instaloader
from datetime import datetime
from itertools import dropwhile, takewhile
import csv

class GetInstagramProfile():
    def __init__(self) -> None:
        self.L = instaloader.Instaloader()

    def download_users_profile_picture(self,username):
        self.L.download_profile(username, profile_pic_only=True)

    def download_users_posts_with_periods(self,username):
        posts = instaloader.Profile.from_username(self.L.context, username).get_posts()
        SINCE = datetime(2021, 8, 28)
        UNTIL = datetime(2021, 9, 30)

        for post in takewhile(lambda p: p.date > SINCE, dropwhile(lambda p: p.date > UNTIL, posts)):
            self.L.download_post(post, username)

    def download_hastag_posts(self, hashtag):
        for post in instaloader.Hashtag.from_name(self.L.context, hashtag).get_posts():
            self.L.download_post(post, target='#'+hashtag)

    def get_users_followers(self,user_name):
#         '''Note: login required to get a profile's followers.'''
        self.L.login(input("input your username: "), input("input your password: ") ) 
        profile = instaloader.Profile.from_username(self.L.context, user_name)
        file = open("follower_names.txt","a+")
        for followee in profile.get_followers():
            username = followee.username
            file.write(username + "\n")
            print(username)

    def get_users_followings(self,user_name):
#         '''Note: login required to get a profile's followings.'''
        self.L.login(input("input your username: "), input("input your password: ") ) 
        profile = instaloader.Profile.from_username(self.L.context, user_name)
        file = open("following_names.txt","a+")
        for followee in profile.get_followees():
            username = followee.username
            file.write(username + "\n")
            print(username)

    def get_post_comments(self,username):
        posts = instaloader.Profile.from_username(self.L.context, username).get_posts()
        for post in posts:
            for comment in post.get_comments():
                print("comment.id  : "+str(comment.id))
                print("comment.owner.username  : "+comment.owner.username)
                print("comment.text  : "+comment.text)
                print("comment.created_at_utc  : "+str(comment.created_at_utc))
                print("************************************************")

    def get_post_info_csv(self,username):
        with open(username+'.csv', 'w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)
            posts = instaloader.Profile.from_username(self.L.context, username).get_posts()
            for post in posts:
                print("post date: "+str(post.date))
                print("post profile: "+post.profile)
                print("post caption: "+post.caption)
                print("post location: "+str(post.location))
                
                posturl = "https://www.instagram.com/p/"+post.shortcode
                print("post url: "+posturl)
                writer.writerow(["post",post.mediaid, post.profile, post.caption, post.date, post.location, posturl,  post.typename, post.mediacount, post.caption_hashtags, post.caption_mentions, post.tagged_users, post.likes, post.comments,  post.title,  post.url ])
            
                for comment in post.get_comments():
                    writer.writerow(["comment",comment.id, comment.owner.username,comment.text,comment.created_at_utc])
                    print("comment username: "+comment.owner.username)
                    print("comment text: "+comment.text)
                    print("comment date : "+str(comment.created_at_utc))
                print("\n\n")


if __name__=="__main__":
    cls = GetInstagramProfile()
    cls.download_users_profile_picture("best_gadgets_2030")
    #cls.download_users_posts_with_periods("best_gadgets_2030")
    #cls.download_hastag_posts("rvcjinsta")
    #cls.get_users_followers("best_gadgets_2030")
    #cls.get_users_followings("best_gadgets_2030")
    #cls.get_post_comments("laydline")
    cls.get_post_info_csv("rvcjinsta")
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\win_unicode_console\__init__.py:31: RuntimeWarning: sys.stdin.encoding == 'cp1252', whereas sys.stdout.encoding == 'UTF-8', readline hook consumer may assume they are the same
#   readline_hook.enable(use_pyreadline=use_pyreadline)
# JSON Query to api/v1/users/web_profile_info/?username=best_gadgets_2030: 404 Not Found [retrying; skip with ^C]
# JSON Query to api/v1/users/web_profile_info/?username=best_gadgets_2030: 404 Not Found [retrying; skip with ^C]
# JSON Query to web/search/topsearch/: HTTP error code 401. [retrying; skip with ^C]
# JSON Query to web/search/topsearch/: HTTP error code 401. [retrying; skip with ^C]
# ---------------------------------------------------------------------------
# QueryReturnedNotFoundException            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     346             if resp.status_code == 404:
# --> 347                 raise QueryReturnedNotFoundException("404 Not Found")
#     348             if resp.status_code == 429:
#
# QueryReturnedNotFoundException: 404 Not Found
#
# During handling of the above exception, another exception occurred:
#
# QueryReturnedNotFoundException            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     346             if resp.status_code == 404:
# --> 347                 raise QueryReturnedNotFoundException("404 Not Found")
#     348             if resp.status_code == 429:
#
# QueryReturnedNotFoundException: 404 Not Found
#
# During handling of the above exception, another exception occurred:
#
# QueryReturnedNotFoundException            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     346             if resp.status_code == 404:
# --> 347                 raise QueryReturnedNotFoundException("404 Not Found")
#     348             if resp.status_code == 429:
#
# QueryReturnedNotFoundException: 404 Not Found
#
# The above exception was the direct cause of the following exception:
#
# QueryReturnedNotFoundException            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\instaloader\structures.py in _obtain_metadata(self)
#     772             if not self._has_full_metadata:
# --> 773                 metadata = self._context.get_iphone_json(f'api/v1/users/web_profile_info/?username={self.username}',
#     774                                                          params={})
#
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_iphone_json(self, path, params)
#     487                 tempsession.headers.pop(header, None)
# --> 488             return self.get_json(path, params, 'i.instagram.com', tempsession)
#     489
#
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     393                         self._rate_controller.handle_429('other')
# --> 394                 return self.get_json(path=path, params=params, host=host, session=sess, _attempt=_attempt + 1)
#     395             except KeyboardInterrupt:
#
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     393                         self._rate_controller.handle_429('other')
# --> 394                 return self.get_json(path=path, params=params, host=host, session=sess, _attempt=_attempt + 1)
#     395             except KeyboardInterrupt:
#
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     381                 if isinstance(err, QueryReturnedNotFoundException):
# --> 382                     raise QueryReturnedNotFoundException(error_string) from err
#     383                 else:
#
# QueryReturnedNotFoundException: JSON Query to api/v1/users/web_profile_info/?username=best_gadgets_2030: 404 Not Found
#
# During handling of the above exception, another exception occurred:
#
# ConnectionException                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     350             if resp.status_code != 200:
# --> 351                 raise ConnectionException("HTTP error code {}.".format(resp.status_code))
#     352             is_html_query = not is_graphql_query and not "__a" in params and host == "www.instagram.com"
#
# ConnectionException: HTTP error code 401.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionException                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     350             if resp.status_code != 200:
# --> 351                 raise ConnectionException("HTTP error code {}.".format(resp.status_code))
#     352             is_html_query = not is_graphql_query and not "__a" in params and host == "www.instagram.com"
#
# ConnectionException: HTTP error code 401.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionException                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     350             if resp.status_code != 200:
# --> 351                 raise ConnectionException("HTTP error code {}.".format(resp.status_code))
#     352             is_html_query = not is_graphql_query and not "__a" in params and host == "www.instagram.com"
#
# ConnectionException: HTTP error code 401.
#
# The above exception was the direct cause of the following exception:
#
# ConnectionException                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17224/166048044.py in <module>
#      77 if __name__=="__main__":
#      78     cls = GetInstagramProfile()
# ---> 79     cls.download_users_profile_picture("best_gadgets_2030")
#      80     #cls.download_users_posts_with_periods("best_gadgets_2030")
#      81     #cls.download_hastag_posts("rvcjinsta")
#
# ~\AppData\Local\Temp/ipykernel_17224/166048044.py in download_users_profile_picture(self, username)
#       9
#      10     def download_users_profile_picture(self,username):
# ---> 11         self.L.download_profile(username, profile_pic_only=True)
#      12
#      13     def download_users_posts_with_periods(self,username):
#
# ~\anaconda3\lib\site-packages\instaloader\instaloader.py in download_profile(self, profile_name, profile_pic, profile_pic_only, fast_update, download_stories, download_stories_only, download_tagged, download_tagged_only, post_filter, storyitem_filter)
#    1500         # and update name and json data if necessary
#    1501         if isinstance(profile_name, str):
# -> 1502             profile = self.check_profile_id(profile_name.lower())
#    1503         else:
#    1504             profile = profile_name
#
# ~\anaconda3\lib\site-packages\instaloader\instaloader.py in check_profile_id(self, profile_name, latest_stamps)
#    1324         profile_name_not_exists_err = None
#    1325         try:
# -> 1326             profile = Profile.from_username(self.context, profile_name)
#    1327         except ProfileNotExistsException as err:
#    1328             profile_name_not_exists_err = err
#
# ~\anaconda3\lib\site-packages\instaloader\structures.py in from_username(cls, context, username)
#     702         # pylint:disable=protected-access
#     703         profile = cls(context, {'username': username.lower()})
# --> 704         profile._obtain_metadata()  # to raise ProfileNotExistsException now in case username is invalid
#     705         return profile
#     706
#
# ~\anaconda3\lib\site-packages\instaloader\structures.py in _obtain_metadata(self)
#     778                 self._has_full_metadata = True
#     779         except (QueryReturnedNotFoundException, KeyError) as err:
# --> 780             top_search_results = TopSearchResults(self._context, self.username)
#     781             similar_profiles = [profile.username for profile in top_search_results.get_profiles()]
#     782             if similar_profiles:
#
# ~\anaconda3\lib\site-packages\instaloader\structures.py in __init__(self, context, searchstring)
#    1719         self._searchstring = searchstring
#    1720         # The `__a` param is only needed to prevent `get_json()` from searching for 'window._sharedData'.
# -> 1721         self._node = context.get_json('web/search/topsearch/',
#    1722                                       params={'context': 'blended',
#    1723                                               'query': searchstring,
#
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     392                     if is_other_query:
#     393                         self._rate_controller.handle_429('other')
# --> 394                 return self.get_json(path=path, params=params, host=host, session=sess, _attempt=_attempt + 1)
#     395             except KeyboardInterrupt:
#     396                 self.error("[skipped by user]", repeat_at_end=False)
#
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     392                     if is_other_query:
#     393                         self._rate_controller.handle_429('other')
# --> 394                 return self.get_json(path=path, params=params, host=host, session=sess, _attempt=_attempt + 1)
#     395             except KeyboardInterrupt:
#     396                 self.error("[skipped by user]", repeat_at_end=False)
#
# ~\anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     382                     raise QueryReturnedNotFoundException(error_string) from err
#     383                 else:
# --> 384                     raise ConnectionException(error_string) from err
#     385             self.error(error_string + " [retrying; skip with ^C]", repeat_at_end=False)
#     386             try:
#
# ConnectionException: JSON Query to web/search/topsearch/: HTTP error code 401.

# %%
from time import sleep
from igramscraper.instagram import Instagram
import pandas as pd
instagram = Instagram()
def check_comments(insta):  
  
  sleep(2) 

  medias = instagram.get_medias(insta, 5)  

  # find all attrs here https://github.com/realsirjoe/instagram-scraper/blob/master/igramscraper/model/media.py
  for media in medias:    
    print(media.comments)
    print(type(media.comments))

# %%
check_comments('9gag')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17224/2167262874.py in <module>
# ----> 1 check_comments('9gag')
#
# ~\AppData\Local\Temp/ipykernel_17224/960986958.py in check_comments(insta)
#       7   sleep(2)
#       8
# ----> 9   medias = instagram.get_medias(insta, 5)
#      10
#      11   # find all attrs here https://github.com/realsirjoe/instagram-scraper/blob/master/igramscraper/model/media.py
#
# ~\Downloads\igramscraper-0.3.5\igramscraper-0.3.5\igramscraper\instagram.py in get_medias(self, username, count, maxId)
#     286         :return: list of Media
#     287         """
# --> 288         account = self.get_account(username)
#     289         return self.get_medias_by_user_id(account.identifier, count, maxId)
#     290
#
# ~\Downloads\igramscraper-0.3.5\igramscraper-0.3.5\igramscraper\instagram.py in get_account(self, username)
#    1125         user_array = Instagram.extract_shared_data_from_body(response.text)
#    1126
# -> 1127         if user_array['entry_data']['ProfilePage'][0]['graphql']['user'] is None:
#    1128             raise InstagramNotFoundException(
#    1129                 'Account with this username does not exist')
#
# TypeError: 'NoneType' object is not subscriptable
