# %%
# https://copyassignment.com/how-to-extract-youtube-comments-using-python/

# GODLY VIDEO
# https://www.youtube.com/watch?v=N--0rmo0ctA&t=2608s
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\asus\anaconda3\lib\site-packages (4.6.3)
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import codecs
f = codecs.open('a.txt', encoding='utf-8', mode='w')
s = "hi everyone"
f.write(unicode(s))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16960/1498996532.py in <module>
#       2 f = codecs.open('a.txt', encoding='utf-8', mode='w')
#       3 s = "hi everyone"
# ----> 4 f.write(unicode(s))
#
# NameError: name 'unicode' is not defined

# %%
# pip install google-api-python-client
from googleapiclient.discovery import build
from datetime import datetime
# For HTML Tags
from bs4 import BeautifulSoup
# For Unicode
import unicodedata
import codecs

video_id = "HDkd_nO1tvA"
api_key = 'AIzaSyDx49S-3eGxX4f1tXmPQjrJMZNUeaiSk0I'

# recursive function to get all replies in a comment thread
def get_replies(comment_id, token):
    replies_response = yt_object.comments().list(part = 'snippet', maxResults = 100, parentId = comment_id, pageToken = token).execute()

    for reply in replies_response['items']:
        all_comments.append(reply['snippet']['textDisplay'])

    if replies_response.get("nextPageToken"):
        return get_replies(comment_id, replies_response['nextPageToken'])
    else:
        return []


# recursive function to get all comments
def get_comments(youtube, video_id, next_view_token):
    global all_comments

    # check for token
    if len(next_view_token.strip()) == 0:
        all_comments = []

    if next_view_token == '':
        # get the initial response
        comment_list = youtube.commentThreads().list(part = 'snippet', maxResults = 100, videoId = video_id, order = 'relevance').execute()
    else:
        # get the next page response
        comment_list = youtube.commentThreads().list(part = 'snippet', maxResults = 100, videoId = video_id, order='relevance', pageToken=next_view_token).execute()
    # loop through all top level comments
    for comment in comment_list['items']:
        # add comment to list
        all_comments.append([comment['snippet']['topLevelComment']['snippet']['textDisplay']])
        all_comments[-1].append(comment['snippet']['topLevelComment']['snippet']['likeCount'])
        # get number of replies
        reply_count = comment['snippet']['totalReplyCount']
        all_replies = []
        # if replies greater than 0
        if reply_count > 0:
            # get first 100 replies
            replies_list = youtube.comments().list(part='snippet', maxResults=100, parentId=comment['id']).execute()
            for reply in replies_list['items']:
                # add reply to list
                all_replies.append(reply['snippet']['textDisplay'])

            # check for more replies
            while "nextPageToken" in replies_list:
                token_reply = replies_list['nextPageToken']
                # get next set of 100 replies
                replies_list = youtube.comments().list(part = 'snippet', maxResults = 1000, parentId = comment['id'], pageToken = token_reply).execute()
                for reply in replies_list['items']:
                    # add reply to list
                    s = reply['snippet']['textDisplay']
#                     s = s.encode("utf-8")
#                     s = s.encode("ascii")
#                     s = s.encode("ISO-8859-1")
#                     s = s.encode("utf-16")
                    all_replies.append(s)

        # add all replies to the comment
        all_comments[-1].append(all_replies[::-1])

    if "nextPageToken" in comment_list:
        return get_comments(youtube, video_id, comment_list['nextPageToken'])
    else:
        return []


all_comments = []

# build a youtube object using our api key
yt_object = build('youtube', 'v3', developerKey=api_key)

# get all comments and replies
comments = get_comments(yt_object, video_id, '')

cnt =0
with open('text.txt', 'w' , encoding="utf-8") as file: 
    date = datetime.now().strftime("%d/%m/%Y %H:%M:%S")
    file.write(date + "\n") 
    for i in all_comments:
        s = str(i)
#         s = s.encode("utf-8")
#         s = s.encode("ascii")
#         s = s.encode("ISO-8859-1")
#         s = s.encode("utf-16")
        s = BeautifulSoup(s, "lxml").text
#         cleantext = unicodedata.normalize('NFKD', cleantext).encode('ascii', 'ignore')
        file.write(s + "\n\n")

# %%
# FORMAT - [Title, Tags, PublishedAt, [comment1, like1, [[reply1, rLike1],[reply2, rLike2],[reply3, rLike3]...]....]

# Limit on API usage Quota
# https://console.cloud.google.com/iam-admin/quotas?walkthrough_id=bigquery--bigquery_quota_request&start_index=1&_ga=2.126615565.1265021502.1676703700-745199028.1676486535&project=nlpstartup#step_index=1

from googleapiclient.discovery import build
from datetime import datetime

api_key = 'AIzaSyDx49S-3eGxX4f1tXmPQjrJMZNUeaiSk0I'
arr = []
def video_comments(video_id):
    with open ('text1.txt', 'w' , encoding="utf-8") as file:  
        now = datetime.now()
        # dd/mm/YY H:M:S
        dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
        file.write(dt_string + "\n") 
        # empty list for storing reply
        # creating youtube resource object
        youtube = build('youtube', 'v3', developerKey=api_key)
        # retrieve youtube video results
        video_response = youtube.commentThreads().list(part='snippet,replies',videoId=video_id).execute()
#         print(video_response)

        # TO GET CHANNEL ID OF A CHANNEL INSPECT AND SEARCH "Channel/"
#         ch_request = youtube.videos().list(part='snippet',id=str(video_id))
#         ch_response = ch_request.execute()
# #         print(ch_response)
#         title = ch_response['items'][0]['snippet']['title']
#         tags = ch_response['items'][0]['snippet']['tags']
#         publishAt = ch_response['items'][0]['snippet']['publishedAt']
#         file.write(title + "\n") 
#         for i in tags:
#             file.write(i + ",") 
#         file.write("\n")
#         file.write(publishAt + "\n") 
        # iterate video response
        while video_response:        
            # extracting required info
            # from each result object 
            for item in video_response['items']:
                com = []

                # Extracting comments
#                 print(item)
#                 comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
                comment = item['snippet']['topLevelComment']['snippet']['textOriginal'] 
                commentLike = item['snippet']['topLevelComment']['snippet']['likeCount']
                com.append(comment)
                com.append(commentLike)
                # counting number of reply of comment
                replycount = item['snippet']['totalReplyCount']

                # if reply is there
                rep = []
                if replycount>0:
                    # iterate through all reply
                    for reply in item['replies']['comments']:
                        r = []
                        # Extract reply
#                         print(reply)
#                         reply = reply['snippet']['textDisplay']
                        replyLike = reply['snippet']['likeCount']
                        reply = reply['snippet']['textOriginal']
                        r.append(reply)
                        r.append(replyLike)

                        # Store reply is list
                        rep.append(r)
                        com.append(rep)
                else:
                    rep.append("")
                    rep.append(0)
                    com.append(rep)
                arr.append(com)
                file.write(str(com)+ "\n")  
                
            break
#             if 'nextPageToken' in video_response:
#                 video_response = youtube.commentThreads().list(part = 'snippet, replies',videoId = video_id).execute()
#             else:
#                 break
#             for i in arr:
#                 print(i)

video_id = "HDkd_nO1tvA"
  
# Call function
video_comments(video_id)

# %%
# GET DETAILS OF A CHANNEL

from googleapiclient.discovery import build
  
# Create YouTube Object
youtube = build('youtube', 'v3', developerKey='AIzaSyDx49S-3eGxX4f1tXmPQjrJMZNUeaiSk0I')
  
# TO GET CHANNEL ID OF A CHANNEL INSPECT AND SEARCH "Channel/"
ch_request = youtube.channels().list(part='statistics',id='UCpYeAw5P9b_8SIxRQtM1l-Q')

# Channel Information
ch_response = ch_request.execute()
print(ch_response)

sub = ch_response['items'][0]['statistics']['subscriberCount']
vid = ch_response['items'][0]['statistics']['videoCount']
views = ch_response['items'][0]['statistics']['viewCount']

print("Total Subscriber:- ", sub)
print("Total Number of Videos:- ", vid)
print("Total Views:- ", views)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'm5FbRYEIIp-02OqOWmY8frjiYd4', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'vvxqXZIDhHJfnNPhvr2evxFY4O4', 'id': 'UCpYeAw5P9b_8SIxRQtM1l-Q', 'statistics': {'viewCount': '66005392', 'subscriberCount': '214000', 'hiddenSubscriberCount': False, 'videoCount': '1271'}}]}
# Total Subscriber:-  214000
# Total Number of Videos:-  1271
# Total Views:-  66005392

# %%
import scrapetube

videos = list(scrapetube.get_channel("UCpYeAw5P9b_8SIxRQtM1l-Q"))
c=0
print(len(videos))
# print(videos['videoId'])
for video in videos:
    c+=1
    print(video['videoId'])
print(c)
# Out:
# 1256
# 6VPd424HAw4
# uXjJujGOkm8
# ey7hvFs_4ng
# MjiPyDVDNZI
# eP2UxUPR2yM
# gNsJ2ZCu6Os
# W7PfXUe1rzA
# a4o4Zm12UtA
# QAXLI0YiU0I
# AxO2873GXHM
# qR58mckfcuo
# bNGrr2CqkkA
# 032O3AtedAs
# XwkFWREpIZI
# fJX8EQJDyVI
# oDxnJe3_w8U
# 4xJBglwer0g
# X2NU20khXmc
# 60v4pQfoQOg
# 22_w4BYE-gQ
# b5IPPec2bsY
# yH2kkOacqwM
# VXp_22IDBLM
# A7FSFqbZ8f8
# 1PdiTpkzMPk
# wdyg0j-oGW8
# JgX9G-DZd30
# 2VXJ5zkiJb4
# iLXI9DRHpog
# 9f3atOAYK1Q
# m8ibYpqrBt8
# BjTi2NHhHhs
# 9ANY_P5EXqs
# Bwp7guJpQiU
# PBkySXHVbHw
# MV3jibINhjU
# AqT_kpG--RA
# Hvjm4cVL7ho
# sTFDuNu7p_U
# LHp8tlAr57o
# IxiXxzllBbU
# YKkpAiwh7wQ
# P1w-UIkybUI
# -E5OyfRyOSE
# R_q2tcvj1Io
# JWGJaUg7cAU
# Q4NOpmkeQ0o
# XMQnNA86L6Q
# lyQWdVjZJCM
# POWX8eG_hM8
# Q0WX_tG3WLs
# PcSy5YimvqQ
# NBQyqQjBF9Q
# fO7KC506U9Q
# syOBXLk8AzA
# LcQIJeMGJ5M
# YxzrmSTwwGE
# BiCzCPb7cdg
# 8AggugzPXDI
# nOMo8VMzK_M
# z59qvOgb8m4
# YmTt69wLIgE
# 4lTfNv92auI
# DUyBocPCZeg
# w8dG6JUIpiM
# 2dZcstU5irg
# V8JNr7NRTBc
# CttwSA9CbVM
# QiNu-cQPT0M
# ldhuN7ojIcs
# 3P7JR6o-X7E
# BUdd9F2_MH0
# sXGnU4aGZaA
# i8ayYPGo1hI
# Y1Bfmw1BV6A
# tqvTie-T25c
# ZznKYm6LVNI
# FNDH5htSoFE
# lFGZDcnPQNM
# JB8EswQI4qE
# J2tNLuI9m94
# IIyhqdnIELI
# 2F0trecbvpU
# 5JTJl1hGCEA
# mW51nH4kGic
# IDECqYpXMzU
# z4Tl30Wa9HM
# WQOzQxNzg4M
# _f_pk6rxAtY
# 44PfHwKxTgA
# lAzpcSLq1sA
# sJk9Q-Dhokc
# mKcgM_i-w0Q
# vFIeWUZE7e4
# gzUu-t-dXIc
# Ryj4u1xls9Q
# OMgKldM4f8M
# jFQ856zS5Hg
# Cm9YfJKkWhc
# 5-F4ncK--AM
# mtZt5RQOjMU
# 2YmzRZ6mxww
# vvDu6tQeVtw
# _X8XqYqdcYI
# elX8wDH8VsA
# wn5SJhrT1pA
# qkPto-rMTbc
# K5SLAHW1svs
# ugV4yCPjS7g
# LcvoP-KIQxg
# UQLFXQeVfUE
# jHrCJksLS5A
# y4RNuJF7hB8
# zBwMB1wGM50
# tHcD644JXY4
# UW9pfgEpy5U
# EE9MHi-zjj4
# w1NyKnGdXvA
# 4zMT_UsYidA
# z6aUzloFv64
# 9-22VQpOILg
# SCBnbBTaDwk
# 1byiynqDcbI
# _9BmZgV_ZsA
# zxC9vLGkhnc
# -Rz1kM4Ek9A
# hbRF3poBX_8
# 7tKI5VF8eKU
# U3Q268sY768
# 6Z7epG_Sk8U
# bVQA0R6HT_k
# wzX4KTrGbbw
# R4qQ7v3nygQ
# dwt793gjU5Q
# K3fAQ7H4Wd4
# LAdazxi4F10
# 3ofXULABkgs
# g8kjphJbHk0
# -BAOsHbnS7k
# ij6D8KJDPas
# ujbaj8AJ7O4
# t4oNj0T2F50
# Xe8kTmnSwto
# 8erZ_DrVplg
# tDkk13fIT7o
# CWi-koZvbvw
# _r4eqQj4OYI
# qfZX6k1SDa0
# 5fNu-dSmryg
# ZmCMyfTC8Rk
# dCvQiCFbbNI
# yDD3NqaMcGo
# wbmDtGz0p0k
# DDSvoeTAtXw
# B91pI4LWkOQ
# DozRWYxipXs
# qLMjq-XBLjk
# DIrkYTQkb3U
# Xy4RJZa3J8o
# sTcZcOw9OzY
# FVKPN8TX4J8
# isnyOhT6pYk
# VNTbTDLpYRk
# fZUQqHj1G5M
# xRCxQSwQgwk
# -Pq1R2DgA-w
# H5EFLgtGjtI
# I-vWdXlL6eg
# wsr81MTM8eA
# VpIT25S5t4s
# Ga5301QsePw
# zeA11abVlUA
# j_qG_lu4TpA
# e4Qk0MFLUEQ
# r-hXmfLYHXM
# O8MODDWpwAQ
# gj9FhahAd4c
# 84LN9GurRn0
# Fifm9LRZmeY
# rX7lGJwcKBo
# udTQXYto2J8
# GdYu6hYH5V0
# EW5CE6coPXM
# 3GNLZVRsxhE
# YlV5DPIjb-8
# IhmKevIYbb4
# 2FdofWxsFFg
# loBaByUhAkg
# KtYV4pMtFQ8
# YNLMX_Byo6k
# 2dG97QdEDNg
# -3B9RwwZFm0
# PtE0JWbZNiY
# 6h34IjAYsSo
# gc646wBFMXk
# Fp72tD1HZ1w
# KBaiWvAyRj4
# xayNzUw3YC0
# UN9U0HV8Fuo
# vCDsr8bgx8c
# Edsk4GJyptk
# 14XgRBJxE0o
# wkgyHCBtuKs
# RqxEVNX3leg
# 6UnJwVYm1Kw
# 3FcC-aGmJOM
# E-CsJIru7AU
# ov4OD8-e2WU
# kJkLFgF2kjY
# va5KNF7kPbI
# 66oxCK4umB0
# KJAyS-pPyUo
# 6XX8LtftLws
# xQYUxvW8Ayg
# BASn36sUIzU
# GyEKYfEyvtY
# f-DwcMcAamc
# _DPmgVXiNew
# QRy5Bm6jm3I
# aFAtvLwO5lE
# RCwTrUUpa5g
# tS4XeTB4AbU
# tBOzcSMfAUQ
# aX3xa6ZHYPk
# DXC1tODqDZg
# CWoHAt9WOhI
# JRvrRu9altc
# OSmE54B77gU
# z9SE3bLY9PY
# 5E4FtaWZXoA
# 4hswZzCWOyY
# 3xXeLr6gWh4
# nIiNqUu6aCI
# JMZWWlM_OoQ
# V7B-nGpv1-0
# e9xP2r-ha0M
# ZaN7FDacdKI
# nCv_aoDMULY
# AueydQPOHx4
# Jk1IuCmLFKY
# I5hKRNMGeOY
# UUEpaYZk_t8
# nxSPxEUpwMc
# YalKonfkeNI
# 0vaJ4pbb0xM
# hnUlsRA9dlM
# LFZeQMzzlss
# 9K5OHwYbFoo
# MNTIlpftnYg
# bHImyM2fVEI
# Zm4C7ERp-4c
# XtG6AXx8hik
# GNoQB2dR8fw
# d2XjSvEDZp0
# pvFow6H1kF4
# zPcqrfa3EmE
# kw7tsjdqllc
# J2bcqMva6Xc
# QTt0TJ1LkE8
# 9M7UJk-kDT0
# yMWHYEhrilE
# ThSWhjaX2to
# GlapT8QYu1U
# itdKZmAKSug
# Eo_TlExEEwc
# HXIHNbd8uAs
# -GqQCYfDVlA
# 9tRr2A_eMDY
# 8wSIJOw6t9I
# fsFf7AfTJbY
# Iwo11u0PBcc
# _UBeNVhguSw
# L4FTo1k0hIU
# 4QmYFBPBaSs
# M45zgyqG7f8
# 6LCVphysabk
# xstiklTJptk
# 1qV2dOMMhRA
# uJUGQgc5Se0
# zIiOlcS1GXE
# na3TtG8TiwI
# m9jUyLgeI00
# NUVRF3kiB6c
# HhdMPFEroWU
# hlfi9KWrmAg
# qhKSy7A0o2g
# M497uOG1uX8
# -J3gJ3B4YOU
# P_cx-Vdj4zo
# 5YYRz9Oyg2E
# PLiEkaxvvwU
# 9NPKD4Uyz0o
# euCQ9Q9VpHM
# S0o-c-YMGK4
# 7tkPYJknFQQ
# qbI58zZN05s
# q7arFumeplg
# YKN2Wh1QDxQ
# L6L7Y0fQYd4
# xwl_YTVrwug
# l2k--NJ9IlI
# ffpS_jgJIPw
# NX6NzLkAxOw
# ryycC0GRmYk
# DJ0_CVgny2A
# C9emOb74--0
# jhnkI7Pv8e0
# 5ZKYQzof9A4
# -m5YLWwzf7w
# rxA73tRfp90
# FRBGHolkDy4
# ZXdHz6dMN9s
# wdbCBaMg2Ww
# 1oRWI0mELGI
# 8_DGy73dKpg
# 1t3BX2fSUiA
# mcOAEyG4MWY
# pG2NqgVc0Qs
# bAVVz5OZBU0
# YxYshVogiAc
# rXf4eNnVp9Q
# NG-4uR5mduk
# WdY-qlbg8bI
# 5EnVON5aaMo
# 6csNRbvOrMM
# lMXG6CPSFvI
# -X7aGba0-CE
# f8_anpdRxwo
# znlXhwTXuc0
# NqZ6ixUqYOk
# NIegAxY0JRI
# 8yUfrce7T1I
# lA1u4WqJxT8
# nRy17tHR4lU
# On1cIhwdlLE
# 0ygZskrF1Po
# 1eJdD_CUXFo
# hbExfmy-SR0
# OMVxReFLw8c
# WrQtyMewPqQ
# A9mm2WJ0xbs
# 0YGLPtY_3KU
# 5QAPFWfHLCo
# cjHx6UxGUMk
# K5oODdJWtvg
# 9Zcdjkrfq6A
# _CjKl7Pi8eQ
# b9k-oiGUxCw
# XlviJ662Vr8
# yyKlMt_EdAQ
# Btn3MLwfkio
# mFTxC-jm08Q
# SYBR2UIImvw
# et7xZgmgRSc
# d3Ea0AZqEeo
# z4nBSeismM4
# pnmCHTXYPqE
# d_JxKjk-rxc
# ZZEW8VWqKqA
# 472g-lP-fWo
# AfpO9nXaG9U
# C4_NQvyb6-U
# jBluHpmQXbI
# xaRTfca9f4k
# qMV3EVP4Qyg
# 1mW9cezhmXA
# ncrGUzbTOCg
# tswlB8zN8i4
# MpxrIjEFrmA
# THbOolMHEdo
# 5kRwWig0sPM
# hk5M3xhUN60
# atqVo2Fv4RQ
# kwmN51QGj_0
# _iQyv2RWP_U
# o4jKYQGAR9g
# AMDr5WJkmz0
# yrt5Nj6iPjo
# OxfMa5eKi0Y
# EWFhfkL7Qww
# -owETTI2Zx8
# pu799GG4Y-8
# dS_IrhkUeVg
# F8G_RLVBw8I
# Tblld88joKU
# -lyWmuskcMU
# J52FrUApc1w
# -ih63Tbn3gI
# ZidiLsBI3vg
# h_vO5XKnVxg
# QGL7OmkPmP0
# LqJNVBq5Efw
# q0bAk5Zigwk
# 8Ez5Qy9nGZY
# 1IZrKKadgZ4
# BCHjHDI6lh0
# t_K01ozj4rI
# rSAt22ODi3w
# XdH_sM0MiXQ
# 9m0M9teg6k0
# IBRQaPUwwkI
# xwY7JfXVlGY
# BYqZjPM-K3Q
# vBvHX0n1XeU
# kskE8KXWO2M
# -x4ATnU22vU
# uWlv3mlv-Mw
# 3eRmQcHU_y4
# nwPUjmVLnnY
# rPvreeLjyDo
# W0R5LfOhQXM
# 4FOAXZtS0cI
# Ip82YBMlRME
# pvTSfMs2VVk
# Pz5Flsjd49o
# fEbgt53COA8
# gkVaOcmscLw
# 5nC-tZkSLao
# tJ5Q8yKdv7U
# 4bCplOitVF8
# g3sfOwHew3o
# tVQGD-OH2kY
# 3xz2QWebsC4
# wQac_G1vKuM
# U5oh0jVHMkA
# ijFpgl8aeXE
# Sl72moXdV2I
# 3rBKV62ymV4
# hTUXreV1l-Y
# F2kQ6DFFQwM
# O7tIZovBGwQ
# cG_9fXCWbrk
# m61EF45g9bE
# pXtnovs78Aw
# c_5qufQ0Rto
# DcsjIOtRjfE
# B8m0tZEsGHA
# zQ5c7vqnSaU
# iTQNi25stYM
# 1256

# %%
# GET A VIDEO'S TITLE, TAG AND PUBLISHTIME

from googleapiclient.discovery import build
  
# Create YouTube Object
youtube = build('youtube', 'v3', developerKey='AIzaSyDx49S-3eGxX4f1tXmPQjrJMZNUeaiSk0I')

# TO GET CHANNEL ID OF A CHANNEL INSPECT AND SEARCH "Channel/"
ch_request = youtube.videos().list(part='snippet',id='YxzrmSTwwGE')

# id = 'UClkDgXr6gVeufWBK7mZ9Q_g'
  
# Channel Information
ch_response = ch_request.execute()
print(ch_response)
print("Title-",ch_response['items'][0]['snippet']['title'])
print("Tags-",ch_response['items'][0]['snippet']['tags'])
print("publishedAt-",ch_response['items'][0]['snippet']['publishedAt'])
  
# sub = ch_response['items'][0]['statistics']['subscriberCount']
# vid = ch_response['items'][0]['statistics']['videoCount']
# views = ch_response['items'][0]['statistics']['viewCount']

# print("Total Subscriber:- ", sub)
# print("Total Number of Videos:- ", vid)
# print("Total Views:- ", views)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': '3bL8zoFoDm_i9H2c4Sv5Ugm1Nvk', 'items': [{'kind': 'youtube#video', 'etag': '8Op908zNeBWr6YqeNEpIF54b2yg', 'id': 'YxzrmSTwwGE', 'snippet': {'publishedAt': '2023-02-17T03:00:16Z', 'channelId': 'UCpYeAw5P9b_8SIxRQtM1l-Q', 'title': 'ALL BALLOONS Skip Townhall WORKS BETTER NOW? (Clash of Clans)', 'description': 'Order pro bases with Blueprint & get 10% off with code: LEXNOS here:\nhttps://blueprintcoc.com/code-LEXNOS\n\nOrder pro bases with Clash Champs & get 10% off with code: LEXNOS here:\nhttps://www.clashchamps.com/shop/\n\nCoC Coaching sessions with ME here:\nhttps://blueprintcoc.com/Lexnos\n\n► 🎮 DISCORD: https://discord.gg/DZ9z3eD9uS\n► 🎮 TWITCH: https://www.twitch.tv/lexnos\n► 🐦 TWITTER: https://twitter.com/Lexnos_\n► 🐦 INSTAGRAM: https://www.instagram.com/lexnos_/\n\nChapters:\n00:00 Kaddiel\n03:19 DEmo\n06:04 Aquiles\n09:13 ipro\n12:21 ND\n15:15 ExoDani\n17:30 BN\n20:45 Hades\n23:16 Dima\n26:08 Elek\n#ClashOfClans #CoC #th15', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/YxzrmSTwwGE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/YxzrmSTwwGE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/YxzrmSTwwGE/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/YxzrmSTwwGE/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/YxzrmSTwwGE/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'Lexnos Gaming', 'tags': ['Clash', 'Lexnos', 'Youtube', '3 star attacks', 'clash of clans', 'guide', 'best attack', 'three star', 'legends', 'war league', 'invisibility', 'dragon', 'update', 'farm', 'klaus', 'pets', 'judo sloth', 'clash of clans challenge', 'clash of clans new event', 'coc new event', 'coc', 'how to beat new challenge', 'new skin', 'clan war league', 'clan game', 'season challenges', 'gold pass', 'clash of clans lets play', 'clash of clans gameplay', 'town hall 15', 'th15', '15', 'th15 gameplay', 'sneak peak', 'th15 sneak peak', 'th 15 update in coc', 'coc th15'], 'categoryId': '20', 'liveBroadcastContent': 'none', 'localized': {'title': 'ALL BALLOONS Skip Townhall WORKS BETTER NOW? (Clash of Clans)', 'description': 'Order pro bases with Blueprint & get 10% off with code: LEXNOS here:\nhttps://blueprintcoc.com/code-LEXNOS\n\nOrder pro bases with Clash Champs & get 10% off with code: LEXNOS here:\nhttps://www.clashchamps.com/shop/\n\nCoC Coaching sessions with ME here:\nhttps://blueprintcoc.com/Lexnos\n\n► 🎮 DISCORD: https://discord.gg/DZ9z3eD9uS\n► 🎮 TWITCH: https://www.twitch.tv/lexnos\n► 🐦 TWITTER: https://twitter.com/Lexnos_\n► 🐦 INSTAGRAM: https://www.instagram.com/lexnos_/\n\nChapters:\n00:00 Kaddiel\n03:19 DEmo\n06:04 Aquiles\n09:13 ipro\n12:21 ND\n15:15 ExoDani\n17:30 BN\n20:45 Hades\n23:16 Dima\n26:08 Elek\n#ClashOfClans #CoC #th15'}, 'defaultAudioLanguage': 'en'}}], 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}
# Title- ALL BALLOONS Skip Townhall WORKS BETTER NOW? (Clash of Clans)
# Tags- ['Clash', 'Lexnos', 'Youtube', '3 star attacks', 'clash of clans', 'guide', 'best attack', 'three star', 'legends', 'war league', 'invisibility', 'dragon', 'update', 'farm', 'klaus', 'pets', 'judo sloth', 'clash of clans challenge', 'clash of clans new event', 'coc new event', 'coc', 'how to beat new challenge', 'new skin', 'clan war league', 'clan game', 'season challenges', 'gold pass', 'clash of clans lets play', 'clash of clans gameplay', 'town hall 15', 'th15', '15', 'th15 gameplay', 'sneak peak', 'th15 sneak peak', 'th 15 update in coc', 'coc th15']
# publishedAt- 2023-02-17T03:00:16Z

# %%
# pip install google-api-python-client
from googleapiclient.discovery import build
from datetime import datetime
# For HTML Tags
from bs4 import BeautifulSoup
# For Unicode
import unicodedata
import codecs

video_id = "HDkd_nO1tvA"
api_key = 'AIzaSyDx49S-3eGxX4f1tXmPQjrJMZNUeaiSk0I'

# recursive function to get all replies in a comment thread
def get_replies(comment_id, token):
    replies_response = yt_object.comments().list(part = 'snippet', maxResults = 100, parentId = comment_id, pageToken = token).execute()

    for reply in replies_response['items']:
        all_comments.append(reply['snippet']['textDisplay'])

    if replies_response.get("nextPageToken"):
        return get_replies(comment_id, replies_response['nextPageToken'])
    else:
        return []


# recursive function to get all comments
def get_comments(youtube, video_id, next_view_token):
    global all_comments

    # check for token
    if len(next_view_token.strip()) == 0:
        all_comments = []

    if next_view_token == '':
        # get the initial response
        comment_list = youtube.commentThreads().list(part = 'snippet', maxResults = 100, videoId = video_id, order = 'relevance').execute()
    else:
        # get the next page response
        comment_list = youtube.commentThreads().list(part = 'snippet', maxResults = 100, videoId = video_id, order='relevance', pageToken=next_view_token).execute()
    # loop through all top level comments
    for comment in comment_list['items']:
        # add comment to list
        ss+=([comment['snippet']['topLevelComment']['snippet']['textDisplay']])
        ss+=",\t"
        ss+=(comment['snippet']['topLevelComment']['snippet']['likeCount'])
        ss+=",\t"
        # get number of replies
        reply_count = comment['snippet']['totalReplyCount']
        all_replies = []
        # if replies greater than 0
        if reply_count > 0:
            # get first 100 replies
            replies_list = youtube.comments().list(part='snippet', maxResults=100, parentId=comment['id']).execute()
            for reply in replies_list['items']:
                # add reply to list
                all_replies.append(reply['snippet']['textDisplay'])

            # check for more replies
            while "nextPageToken" in replies_list:
                token_reply = replies_list['nextPageToken']
                # get next set of 100 replies
                replies_list = youtube.comments().list(part = 'snippet', maxResults = 1000, parentId = comment['id'], pageToken = token_reply).execute()
                for reply in replies_list['items']:
                    # add reply to list
                    s = reply['snippet']['textDisplay']
                    all_replies.append(s)

        # add all replies to the comment
        sss+=(all_replies[::-1])

    if "nextPageToken" in comment_list:
        return get_comments(youtube, video_id, comment_list['nextPageToken'])
    else:
        return []


all_comments = []

# build a youtube object using our api key
yt_object = build('youtube', 'v3', developerKey=api_key)

# get all comments and replies
comments = get_comments(yt_object, video_id, '')

cnt =0
with open('text.txt', 'w' , encoding="utf-8") as file: 
    date = datetime.now().strftime("%d/%m/%Y %H:%M:%S")
    file.write(date + "\n") 
    for i in all_comments:
        s = str(i)
#         s = s.encode("utf-8")
#         s = s.encode("ascii")
#         s = s.encode("ISO-8859-1")
#         s = s.encode("utf-16")
        s = BeautifulSoup(s, "lxml").text
#         cleantext = unicodedata.normalize('NFKD', cleantext).encode('ascii', 'ignore')
        file.write(s + "\n\n")

# %%
# FORMAT - [Title, Tags, PublishedAt, [comment1, like1, [[reply1, rLike1],[reply2, rLike2],[reply3, rLike3]...]....]

# Limit on API usage Quota
# https://console.cloud.google.com/iam-admin/quotas?walkthrough_id=bigquery--bigquery_quota_request&start_index=1&_ga=2.126615565.1265021502.1676703700-745199028.1676486535&project=nlpstartup#step_index=1

from googleapiclient.discovery import build
from datetime import datetime
  
api_key = 'AIzaSyDx49S-3eGxX4f1tXmPQjrJMZNUeaiSk0I'
arr = []
def video_comments(video_id):
    # creating youtube resource object
    youtube = build('youtube', 'v3', developerKey=api_key)
    # retrieve youtube video results
    video_response = youtube.commentThreads().list(part='snippet,replies',videoId=video_id).execute()
    while video_response:        
        # extracting required info
        # from each result object 
        for item in video_response['items']:
            com = []

            # Extracting comments
#                 print(item)
#                 comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comment = item['snippet']['topLevelComment']['snippet']['textOriginal'] 
            commentLike = item['snippet']['topLevelComment']['snippet']['likeCount']
            com.append(comment)
            com.append(commentLike)
            # counting number of reply of comment
            replycount = item['snippet']['totalReplyCount']

            # if reply is there
            rep = []
            if replycount>0:
                # iterate through all reply
                for reply in item['replies']['comments']:
                    r = []
                    # Extract reply
#                         print(reply)
#                         reply = reply['snippet']['textDisplay']
                    replyLike = reply['snippet']['likeCount']
                    reply = reply['snippet']['textOriginal']
                    r.append(reply)
                    r.append(replyLike)

                    # Store reply is list
                    rep.append(r)
                    com.append(rep)
            else:
                rep.append("")
                rep.append(0)
                com.append(rep)
            arr.append(com)
#             file.write(str(com)+ "\n")  

        if 'nextPageToken' in video_response:
            video_response = youtube.commentThreads().list(part = 'snippet, replies',videoId = video_id).execute()
        else:
            print(arr)
            break

video_id = "E5OyfRyOSE"
  
# Call function
video_comments(video_id)
# Out:
#   File "C:\Users\Asus\AppData\Local\Temp/ipykernel_21068/965692051.py", line 60
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
from googleapiclient.discovery import build
 
api_key = 'AIzaSyDx49S-3eGxX4f1tXmPQjrJMZNUeaiSk0I'
 
def video_comments(video_id):
    # empty list for storing reply
    replies = []
 
    # creating youtube resource object
    youtube = build('youtube', 'v3',
                    developerKey=api_key)
 
    # retrieve youtube video results
    video_response=youtube.commentThreads().list(
    part='snippet,replies',
    videoId=video_id
    ).execute()
 
    # iterate video response
    while video_response:
       
        # extracting required info
        # from each result object
        for item in video_response['items']:
           
            # Extracting comments
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
             
            # counting number of reply of comment
            replycount = item['snippet']['totalReplyCount']
 
            # if reply is there
            if replycount>0:
               
                # iterate through all reply
                for reply in item['replies']['comments']:
                   
                    # Extract reply
                    reply = reply['snippet']['textDisplay']
                     
                    # Store reply is list
                    replies.append(reply)
 
            # print comment with list of reply
            print(comment, replies, end = '\n\n')
 
            # empty reply list
            replies = []
 
        # Again repeat
        if 'nextPageToken' in video_response:
            video_response = youtube.commentThreads().list(
                    part = 'snippet,replies',
                    videoId = video_id
                ).execute()
        else:
            break
 
# Enter video id
video_id = "HWfRZY8TVJ4"
 
# Call function
video_comments(video_id)
# Out:
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# ...
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []
#
# Radhe Radhe✨❤️🙌🏻 []
#
# I wish people who do not understand Hindi could only feel the real meaning of this song or even &#39;Prem&#39; it can not be translated to any other language. []
#
# Song <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=6m42s">6:42</a> to <a href="https://www.youtube.com/watch?v=HWfRZY8TVJ4&amp;t=7m11s">7:11</a>, Goosebumps. . Hare Krishna .. Radhe Radhe []
#
# It&#39;s superb 😊 []
#
# Wow Jai shree Krishna it&#39;s too soft song I love it 😌 Radha Krishna []
#
# 🙏🙏🙏🙏🙏♥️♥️♥️♥️♥️♥️♥️ []
#
# Radhe radhe 🙏 []
#
# I used not to believe god . Now look at me ,this song takes place in my heart ❤ []
#
# I really like this song this gives me so much peace and legit takes all my tension .. I love you godd no matter what and I will always love and respect your decisions for me ❤ []
#
# Pyr ho toh radha krishna jesa ho shiv  parbati jesi ho abba maa ki tarha ho Heer ranjha jesa ho []
#
# आखरी सांस तक राधे राधे []
#
# Jay shree krishna... .... []
#
# Sukoon💞💞💝❣️❤❣️❤❣️❤❣️❤❣️❤❣️....wanna dedicate this song to my family nd my 👻❤❤ []
#
# Radhe. ❤️❤️Radhe❤️❤️   Krishna hare Krishna Radhe Radheshyam Vishwakarma 🙏❤️🌹 []
#
# there&#39;s nothing beyond this song !!!!!!!!!!!!!!!<br>🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏 []
#
# ❤️🙏jai shree radhe krishna ji🙏❤️ []
#
# Jai Sri Krishna 💗🙏 []
#
# Hare Krishna ❤ []
#
# 𝙅𝙖𝙮 𝙨𝙝𝙧𝙚𝙚 𝙍𝙖𝙙𝙝𝙖 𝙠𝙧𝙞𝙨𝙝𝙣𝙖 ❤ []

# %%
# pip install google-api-python-client
from googleapiclient.discovery import build
from datetime import datetime
# For HTML Tags
from bs4 import BeautifulSoup
# For Unicode
import unicodedata
import codecs

video_id = "HDkd_nO1tvA"
api_key = 'AIzaSyDx49S-3eGxX4f1tXmPQjrJMZNUeaiSk0I'

# # recursive function to get all replies in a comment thread
# def get_replies(comment_id, token):
#     replies_response = yt_object.comments().list(part = 'snippet', maxResults = 100, parentId = comment_id, pageToken = token).execute()

#     for reply in replies_response['items']:
#         all_comments.append(reply['snippet']['textDisplay'])

#     if replies_response.get("nextPageToken"):
#         return get_replies(comment_id, replies_response['nextPageToken'])
#     else:
#         return []


# recursive function to get all comments
d={}
def get_comments(youtube, video_id, next_view_token):
    global all_comments
    
    # check for token
    if len(next_view_token.strip()) == 0:
        all_comments = {}

    if next_view_token == '':
        # get the initial response
        comment_list = youtube.commentThreads().list(part = 'snippet', maxResults = 100, videoId = video_id, order = 'relevance').execute()
    else:
        # get the next page response
        comment_list = youtube.commentThreads().list(part = 'snippet', maxResults = 100, videoId = video_id, order='relevance', pageToken=next_view_token).execute()
    # loop through all top level comments
    id = 0
    for comment in comment_list['items']:
        id += 1
        # add comment to list
        all_comments["comment"] = comment['snippet']['topLevelComment']['snippet']['textDisplay']
        all_comments["commentLike"] = comment['snippet']['topLevelComment']['snippet']['likeCount']
        # get number of replies
        reply_count = comment['snippet']['totalReplyCount']
        all_replies = []
        # if replies greater than 0
        if reply_count > 0:
            # get first 100 replies
            replies_list = youtube.comments().list(part='snippet', maxResults=100, parentId=comment['id']).execute()
            for reply in replies_list['items']:
                # add reply to list
                all_replies.append(reply['snippet']['textDisplay'])

            # check for more replies
            while "nextPageToken" in replies_list:
                token_reply = replies_list['nextPageToken']
                # get next set of 100 replies
                replies_list = youtube.comments().list(part = 'snippet', maxResults = 1000, parentId = comment['id'], pageToken = token_reply).execute()
                for reply in replies_list['items']:
                    # add reply to list
                    s = reply['snippet']['textDisplay']
                    all_replies.append(s)

        # add all replies to the comment
        all_comments["replies"] = all_replies[::-1]
        d[id] = all_comments

    if "nextPageToken" in comment_list:
        return get_comments(youtube, video_id, comment_list['nextPageToken'])
    else:
        return []


all_comments = {}
# build a youtube object using our api key
yt_object = build('youtube', 'v3', developerKey=api_key)

# get all comments and replies
comments = get_comments(yt_object, video_id, '')

cnt =0
print(d)
# with open('text.txt', 'w' , encoding="utf-8") as file: 
#     date = datetime.now().strftime("%d/%m/%Y %H:%M:%S")
#     file.write(date + "\n") 
#     for i in all_comments:
#         s = str(i)
#         s = BeautifulSoup(s, "lxml").text
# #         cleantext = unicodedata.normalize('NFKD', cleantext).encode('ascii', 'ignore')
#         file.write(s + "\n\n")
# Out:
# {1: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 2: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 3: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 4: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 5: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 6: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 7: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 8: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 9: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 10: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 11: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 12: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 13: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 14: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 15: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 16: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 17: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 18: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 19: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 20: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 21: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 22: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 23: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 24: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 25: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 26: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 27: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 28: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 29: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 30: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 31: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 32: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 33: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 34: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 35: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 36: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 37: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 38: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 39: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 40: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 41: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 42: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 43: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 44: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 45: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 46: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 47: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 48: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 49: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 50: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 51: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 52: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 53: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 54: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 55: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 56: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 57: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 58: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 59: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 60: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 61: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 62: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 63: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 64: {'comment': 'Always 2', 'commentLike': 0, 'replies': []}, 65: {'comment': 'Always 2', 'commentLike ...

# %%
# pip install google-api-python-client
from googleapiclient.discovery import build
from datetime import datetime
# For HTML Tags
from bs4 import BeautifulSoup
# For Unicode
import unicodedata
import codecs

video_id = "HDkd_nO1tvA"
api_key = 'AIzaSyDx49S-3eGxX4f1tXmPQjrJMZNUeaiSk0I'

# recursive function to get all replies in a comment thread
def get_replies(comment_id, token):
    replies_response = yt_object.comments().list(part = 'snippet', maxResults = 100, parentId = comment_id, pageToken = token).execute()

    for reply in replies_response['items']:
        all_comments.append(reply['snippet']['textDisplay'])

    if replies_response.get("nextPageToken"):
        return get_replies(comment_id, replies_response['nextPageToken'])
    else:
        return []


# recursive function to get all comments
def get_comments(youtube, video_id, next_view_token):
    global all_comments

    # check for token
    if len(next_view_token.strip()) == 0:
        all_comments = []

    if next_view_token == '':
        # get the initial response
        comment_list = youtube.commentThreads().list(part = 'snippet', maxResults = 100, videoId = video_id, order = 'relevance').execute()
    else:
        # get the next page response
        comment_list = youtube.commentThreads().list(part = 'snippet', maxResults = 100, videoId = video_id, order='relevance', pageToken=next_view_token).execute()
    # loop through all top level comments
    for comment in comment_list['items']:
        # add comment to list
        all_comments.append([comment['snippet']['topLevelComment']['snippet']['textDisplay']])
        all_comments[-1].append(comment['snippet']['topLevelComment']['snippet']['likeCount'])
        # get number of replies
        reply_count = comment['snippet']['totalReplyCount']
        all_replies = []
        # if replies greater than 0
        if reply_count > 0:
            # get first 100 replies
            replies_list = youtube.comments().list(part='snippet', maxResults=100, parentId=comment['id']).execute()
            for reply in replies_list['items']:
                # add reply to list
                all_replies.append(reply['snippet']['textDisplay'])

            # check for more replies
            while "nextPageToken" in replies_list:
                token_reply = replies_list['nextPageToken']
                # get next set of 100 replies
                replies_list = youtube.comments().list(part = 'snippet', maxResults = 1000, parentId = comment['id'], pageToken = token_reply).execute()
                for reply in replies_list['items']:
                    # add reply to list
                    s = reply['snippet']['textDisplay']
#                     s = s.encode("utf-8")
#                     s = s.encode("ascii")
#                     s = s.encode("ISO-8859-1")
#                     s = s.encode("utf-16")
                    all_replies.append(s)

        # add all replies to the comment
        all_comments[-1].append(all_replies[::-1])

    if "nextPageToken" in comment_list:
        return get_comments(youtube, video_id, comment_list['nextPageToken'])
    else:
        return []


all_comments = []

# build a youtube object using our api key
yt_object = build('youtube', 'v3', developerKey=api_key)

# get all comments and replies
comments = get_comments(yt_object, video_id, '')

# cnt =0
# with open('text.txt', 'w' , encoding="utf-8") as file: 
#     date = datetime.now().strftime("%d/%m/%Y %H:%M:%S")
#     file.write(date + "\n") 
#     for i in all_comments:
#         s = str(i)
# #         s = s.encode("utf-8")
# #         s = s.encode("ascii")
# #         s = s.encode("ISO-8859-1")
# #         s = s.encode("utf-16")
#         s = BeautifulSoup(s, "lxml").text
# #         cleantext = unicodedata.normalize('NFKD', cleantext).encode('ascii', 'ignore')
#         file.write(s + "\n\n")

# %%
with open('comments1.pkl', 'wb') as file: 
    pickle.dump(all_comments,file)

# %%
s = []
with open('comments.pkl', 'rb') as file: 
    s.append(pickle.load(file))

# %%
print(s)
# Out:
# [{1: {'comment': 'To be honest for it&#39;s price, it&#39;s a very bad phone', 'commentLike': 0, 'replies': ['They should sell it more cheaper', '@Nikki Cherry I do agree with you but the thing is for the price yes it’s expensive but you get a lot of quality', '@Denise Shephard nope, it should be $700 maximum for the starting price. For $900, you’re better off buying a 13 pro or pro max instead']}, 2: {'comment': 'To be honest for it&#39;s price, it&#39;s a very bad phone', 'commentLike': 0, 'replies': ['They should sell it more cheaper', '@Nikki Cherry I do agree with you but the thing is for the price yes it’s expensive but you get a lot of quality', '@Denise Shephard nope, it should be $700 maximum for the starting price. For $900, you’re better off buying a 13 pro or pro max instead']}, 3: {'comment': 'To be honest for it&#39;s price, it&#39;s a very bad phone', 'commentLike': 0, 'replies': ['They should sell it more cheaper', '@Nikki Cherry I do agree with you but the thing is for the price yes it’s expensive but you get a lot of quality', '@Denise Shephard nope, it should be $700 maximum for the starting price. For $900, you’re better off buying a 13 pro or pro max instead']}, 4: {'comment': 'To be honest for it&#39;s price, it&#39;s a very bad phone', 'commentLike': 0, 'replies': ['They should sell it more cheaper', '@Nikki Cherry I do agree with you but the thing is for the price yes it’s expensive but you get a lot of quality', '@Denise Shephard nope, it should be $700 maximum for the starting price. For $900, you’re better off buying a 13 pro or pro max instead']}, 5: {'comment': 'To be honest for it&#39;s price, it&#39;s a very bad phone', 'commentLike': 0, 'replies': ['They should sell it more cheaper', '@Nikki Cherry I do agree with you but the thing is for the price yes it’s expensive but you get a lot of quality', '@Denise Shephard nope, it should be $700 maximum for the starting price. For $900, you’re better off buying a 13 pro or pro max instead']}, 6: {'comment': 'To be honest for it&#39;s price, it&#39;s a very bad phone', 'commentLike': 0, 'replies': ['They should sell it more cheaper', '@Nikki Cherry I do agree with you but the thing is for the price yes it’s expensive but you get a lot of quality', '@Denise Shephard nope, it should be $700 maximum for the starting price. For $900, you’re better off buying a 13 pro or pro max instead']}, 7: {'comment': 'To be honest for it&#39;s price, it&#39;s a very bad phone', 'commentLike': 0, 'replies': ['They should sell it more cheaper', '@Nikki Cherry I do agree with you but the thing is for the price yes it’s expensive but you get a lot of quality', '@Denise Shephard nope, it should be $700 maximum for the starting price. For $900, you’re better off buying a 13 pro or pro max instead']}, 8: {'comment': 'To be honest for it&#39;s price, it&#39;s a very bad phone', 'commentLike': 0, 'replies': ['They should sell it more cheaper', '@Nikki Cherry I do agree with you but the thing is for the price yes it’s expensive but you get a lot of quality', '@Denise Shephard nope, it should be $700 maximum for the starting price. For $900, you’re better off buying a 13 pro or pro max instead']}, 9: {'comment': 'To be honest for it&#39;s price, it&#39;s a very bad phone', 'commentLike': 0, 'replies': ['They should sell it more cheaper', '@Nikki Cherry I do agree with you but the thing is for the price yes it’s expensive but you get a lot of quality', '@Denise Shephard nope, it should be $700 maximum for the starting price. For $900, you’re better off buying a 13 pro or pro max instead']}}]
